# %%
import pandas as pd
import pathlib as pl
import numpy as np

# %%
people_df=pd.read_csv("people1.csv")

# %%
people_df.head()
# Out:
#     id first_name    last_name                            email  gender  \
# 0  1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1  2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 2  3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3  4.0     Cullie          NaN               cputten3@nymag.com    Male
# 4  5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                             uni_grad           job_title  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Income
# 0  58135.0
# 1  96053.0
# 2  59196.0
# 3  88493.0
# 4  89073.0

# %%
people_df.describe(include='all')
# Out:
#                  id first_name    last_name                 email gender  \
# count    996.000000        993          990                   992    998
# unique          NaN        914          974                   991      2
# top             NaN    Ailbert  Giovannacci  ayang@codedrills.com   Male
# freq            NaN          3            2                     2    508
# mean     500.213855        NaN          NaN                   NaN    NaN
# std      289.172174        NaN          NaN                   NaN    NaN
# min        1.000000        NaN          NaN                   NaN    NaN
# 25%      249.750000        NaN          NaN                   NaN    NaN
# 50%      500.000000        NaN          NaN                   NaN    NaN
# 75%      750.250000        NaN          NaN                   NaN    NaN
# max     1000.000000        NaN          NaN                   NaN    NaN
#
#                       uni_grad              job_title         Income
# ...

# %%
## 02

# %%
people_df=pd.read_csv("people2.csv")
people_df.head()
# Out:
#     id first_name    last_name                            email  gender  \
# 0  1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1  2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 2  3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3  4.0     Cullie          NaN               cputten3@nymag.com    Male
# 4  5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                             uni_grad           job_title  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Income
# 0  58135.0
# 1  96053.0
# 2  59196.0
# 3  88493.0
# 4  89073.0

# %%
people_df.describe()
# Out:
#                 id         Income
# count   996.000000     998.000000
# mean    500.213855   84691.693387
# std     289.172174   20185.664319
# min       1.000000   50013.000000
# 25%     249.750000   67353.000000
# 50%     500.000000   84296.000000
# 75%     750.250000  102374.750000
# max    1000.000000  119987.000000

# %%
people_df.shape
# Out:
# (1000, 8)

# %%
people_df.columns=["Person_ID", "First_Name", "Last_Name", "Email", "Gender", "University", "Occupation", "Salary"]

# %%
people_df.head()
# Out:
#    Person_ID First_Name    Last_Name                            Email  Gender  \
# 0        1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1        2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 2        3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3        4.0     Cullie          NaN               cputten3@nymag.com    Male
# 4        5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary
# 0  58135.0
# 1  96053.0
# 2  59196.0
# ...

# %%
peopled_df={}
peopled_df=pd.columns = {"Person_ID", "First_Name", "Last_Name", "Email", "Gender", "University", "Occupation", "Salary"}

# %%
people_df.head()
# Out:
#    Person_ID First_Name    Last_Name                            Email  Gender  \
# 0        1.0    Keriann    Lenormand  klenormand0@businessinsider.com  Female
# 1        2.0    Huntley        Rupke              hrupke1@reuters.com    Male
# 2        3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com    Male
# 3        4.0     Cullie          NaN               cputten3@nymag.com    Male
# 4        5.0      Ariel    Strangman       astrangman4@bravesites.com  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary
# 0  58135.0
# 1  96053.0
# 2  59196.0
# ...

# %%
people_df.columns=["Person_ID", "First_Name", "Last_Name", "Gender", "University", "Occupation", "Salary", "Email"]

# %%
people_df.insert=(3, "Age")

# %%
people_df.head()
# Out:
#    Person_ID First_Name    Last_Name                           Gender  \
# 0        1.0    Keriann    Lenormand  klenormand0@businessinsider.com
# 1        2.0    Huntley        Rupke              hrupke1@reuters.com
# 2        3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com
# 3        4.0     Cullie          NaN               cputten3@nymag.com
# 4        5.0      Ariel    Strangman       astrangman4@bravesites.com
#
#   University                                         Occupation  \
# 0     Female                                  Aurora University
# 1       Male                      Osaka University of Economics
# 2       Male                                  Ludong University
# 3       Male  Université des Sciences et de la Technologie d...
# 4     Female                             Boise State University
#
#                Salary    Email
# 0  Nurse Practicioner  58135.0
# 1     Project Manager  96053.0
# 2  Environmental Tech  59196.0
# ...

# %%
people_df["Age"]= np.random.randint(low=22, high=65, size=1000)

# %%
people_df.head()
# Out:
#    Person_ID First_Name    Last_Name                           Gender  \
# 0        1.0    Keriann    Lenormand  klenormand0@businessinsider.com
# 1        2.0    Huntley        Rupke              hrupke1@reuters.com
# 2        3.0     Gorden  Dalgarnowch      gdalgarnowch2@microsoft.com
# 3        4.0     Cullie          NaN               cputten3@nymag.com
# 4        5.0      Ariel    Strangman       astrangman4@bravesites.com
#
#   University                                         Occupation  \
# 0     Female                                  Aurora University
# 1       Male                      Osaka University of Economics
# 2       Male                                  Ludong University
# 3       Male  Université des Sciences et de la Technologie d...
# 4     Female                             Boise State University
#
#                Salary    Email  Age
# 0  Nurse Practicioner  58135.0   60
# 1     Project Manager  96053.0   48
# 2  Environmental Tech  59196.0   48
# ...

# %%
people_df.to_csv("output.csv",index=False)

# %%
### 03

# %%
people_re_df=pd.read_csv("people_reordered.csv")

# %%
people_re_df.head()
# Out:
#    Unnamed: 0  Person_ID    Last_Name First_Name  Gender  \
# 0           0        1.0    Lenormand    Keriann  Female
# 1           1        2.0        Rupke    Huntley    Male
# 2           2        3.0  Dalgarnowch     Gorden    Male
# 3           3        4.0          NaN     Cullie    Male
# 4           4        5.0    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email  Age
# 0  58135.0  klenormand0@businessinsider.com   27
# 1  96053.0              hrupke1@reuters.com   22
# ...

# %%
people_re_df.shape
# Out:
# (1000, 10)

# %%
people_re_df.isnull().any()  ## check for missing info
# Out:
# Unnamed: 0    False
# Person_ID      True
# Last_Name      True
# First_Name     True
# Gender         True
# University     True
# Occupation     True
# Salary         True
# Email          True
# Age           False
# dtype: bool

# %%
people_re_df.groupby()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-154-09a3525651e8> in <module>
# ----> 1 people_re_df.groupby()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6506
#    6507         if level is None and by is None:
# -> 6508             raise TypeError("You have to supply one of 'by' and 'level'")
#    6509         axis = self._get_axis_number(axis)
#    6510
#
# TypeError: You have to supply one of 'by' and 'level'

# %%
people_re_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   int64
#  1   Person_ID   996 non-null    float64
#  2   Last_Name   990 non-null    object
#  3   First_Name  993 non-null    object
#  4   Gender      998 non-null    object
#  5   University  991 non-null    object
#  6   Occupation  998 non-null    object
#  7   Salary      998 non-null    float64
#  8   Email       992 non-null    object
#  9   Age         1000 non-null   int64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 78.2+ KB

# %%
people_re_df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
people_re_df.shape
# Out:
# (1000, 9)

# %%
people_re_df.value_counts()
# Out:
# Person_ID  Last_Name    First_Name  Gender  University                                   Occupation                  Salary    Email                              Age
# 999.0      Yang         Andrew      Male    Rutgers University School of Business        Curriculum Engineer         60000.0   ayang@codedrills.com               53     2
# 329.0      Kingsbury    Harlin      Male    Universidad de Cantabria                     Programmer Analyst I        74144.0   hkingsbury94@europa.eu             60     1
# 342.0      Haggard      Willi       Female  Oral Roberts University                      Systems Administrator III   113945.0  whaggard9h@foxnews.com             47     1
# 340.0      Le Marchand  Pancho      Male    University of Maryland Medicine              Automation Specialist I     50176.0   plemarchand9f@issuu.com            60     1
# ...

# %%
people_re_df.describe()
# Out:
#         Person_ID         Salary          Age
# count  996.000000     998.000000  1000.000000
# mean   500.212851   84691.693387    42.965000
# std    289.170439   20185.664319    12.346263
# min      1.000000   50013.000000    22.000000
# 25%    249.750000   67353.000000    33.000000
# 50%    500.000000   84296.000000    42.000000
# 75%    750.250000  102374.750000    54.000000
# max    999.000000  119987.000000    64.000000

# %%
people_re_df.groupby("First_Name").count()
# Out:
#             Person_ID  Last_Name  Gender  University  Occupation  Salary  \
# First_Name
# Aaron               1          1       1           1           1       1
# Abbot               1          1       1           1           1       1
# Abbye               1          1       1           1           1       1
# Abner               1          1       1           1           1       1
# Abra                1          1       1           1           1       1
# ...               ...        ...     ...         ...         ...     ...
# Zandra              1          1       1           1           1       1
# Zebedee             0          1       1           1           1       1
# Zebulon             1          1       1           1           1       1
# Zerk                1          1       1           1           1       1
# Zsazsa              1          1       1           1           1       1
#
#             Email  Age
# First_Name
# Aaron           1    1
# ...

# %%
people_re_df.groupby("First_Name")["Person_ID"].count()
# Out:
# First_Name
# Aaron      1
# Abbot      1
# Abbye      1
# Abner      1
# Abra       1
#           ..
# Zandra     1
# Zebedee    0
# Zebulon    1
# Zerk       1
# Zsazsa     1
# Name: Person_ID, Length: 914, dtype: int64

# %%
people_re_df.isnull()
# Out:
#      Person_ID  Last_Name  First_Name  Gender  University  Occupation  Salary  \
# 0        False      False       False   False       False       False   False
# 1        False      False       False   False       False       False   False
# 2        False      False       False   False       False       False   False
# 3        False       True       False   False       False       False   False
# 4        False      False       False   False       False       False   False
# ..         ...        ...         ...     ...         ...         ...     ...
# 995      False      False       False   False       False       False   False
# 996      False      False       False   False       False       False   False
# 997      False      False       False   False       False       False   False
# 998      False      False       False   False       False       False   False
# 999      False      False       False   False       False       False   False
#
#      Email    Age
# ...

# %%
sum_df=people_re_df.isnull().sum()

# %%
sum_df
# Out:
# Person_ID      4
# Last_Name     10
# First_Name     7
# Gender         2
# University     9
# Occupation     2
# Salary         2
# Email          8
# Age            0
# dtype: int64

# %%
per_df=(sum_df/1000)*100
print(per_df)
# Out:
# Person_ID     0.4
# Last_Name     1.0
# First_Name    0.7
# Gender        0.2
# University    0.9
# Occupation    0.2
# Salary        0.2
# Email         0.8
# Age           0.0
# dtype: float64

# %%
people_re_df.head()
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0        1.0    Lenormand    Keriann  Female
# 1        2.0        Rupke    Huntley    Male
# 2        3.0  Dalgarnowch     Gorden    Male
# 3        4.0          NaN     Cullie    Male
# 4        5.0    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email  Age
# 0  58135.0  klenormand0@businessinsider.com   27
# 1  96053.0              hrupke1@reuters.com   22
# 2  59196.0      gdalgarnowch2@microsoft.com   40
# 3  88493.0               cputten3@nymag.com   62
# ...

# %%
people_re_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999     True
# Length: 1000, dtype: bool

# %%
people_re_df[["First_Name", "Last_Name"]].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999     True
# Length: 1000, dtype: bool

# %%
people_re_df["First_Name"].fillna(value = "Unnamed", inplace = True)

# %%
people_re_df["Last_Name"].fillna(value = "Unnamed", inplace = True)

# %%
people_re_df.head()
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0        1.0    Lenormand    Keriann  Female
# 1        2.0        Rupke    Huntley    Male
# 2        3.0  Dalgarnowch     Gorden    Male
# 3        4.0      Unnamed     Cullie    Male
# 4        5.0    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email  Age
# 0  58135.0  klenormand0@businessinsider.com   27
# 1  96053.0              hrupke1@reuters.com   22
# 2  59196.0      gdalgarnowch2@microsoft.com   40
# 3  88493.0               cputten3@nymag.com   62
# ...

# %%
people_re_df.dropna(inplace = True)

# %%
people_re_df["Person_ID"] = people_re_df["Person_ID"].astype(int)

# %%
people_re_df.to_csv("cleansed date output.csv",index=False)

# %%
people_re_df.dtypes
# Out:
# Person_ID       int32
# Last_Name      object
# First_Name     object
# Gender         object
# University     object
# Occupation     object
# Salary        float64
# Email          object
# Age             int64
# dtype: object
