# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
menu_file = Path("menu_data.csv")
sales_file = Path("sales_data.csv")
menu = []
sales = []

# %%
menu = pd.read_csv(menu_file)
sales = pd.read_csv(sales_file)

# %%
menu_df=pd.DataFrame(menu)
sales_df= pd.DataFrame(sales)

# %%
sales_df
# Out:
#        Line_Item_ID        Date  Credit_Card_Number  Quantity  \
# 0                 1  01-01-2017    7437926611570799         1
# 1                 2  01-01-2017    7437926611570799         1
# 2                 3  01-01-2017    8421920068932819         3
# 3                 4  01-01-2017    8421920068932819         3
# 4                 5  01-01-2017    4787310681569648         1
# ...             ...         ...                 ...       ...
# 74119         74120  12-31-2018    1697055332228941         4
# 74120         74121  12-31-2018    6800009643487106         1
# 74121         74122  12-31-2018    6800009643487106         1
# 74122         74123  12-31-2018    5981057609583653         2
# 74123         74124  12-31-2018    5981057609583653         2
#
#                    Menu_Item
# 0           spicy miso ramen
# 1           spicy miso ramen
# 2          tori paitan ramen
# 3          tori paitan ramen
# 4       truffle butter ramen
# ...                      ...
# 74119         tonkotsu ramen
# 74120  vegetarian spicy miso
# 74121  vegetarian spicy miso
# 74122       spicy miso ramen
# 74123       spicy miso ramen
#
# [74124 rows x 5 columns]

# %%
menu_df.head()
# Out:
#                            item    category  \
# 0                       edamame  appetizers
# 1                   house salad  appetizers
# 2       cucumber sunomono salad  appetizers
# 3  hiyashi wakame seaweed salad  appetizers
# 4                 agedashi tofu  appetizers
#
#                                          description  price  cost
# 0                   boiled soybeans, maldon sea salt    4.0     1
# 1  mixed greens, cherry tomatoes, cucumber, house...    4.0     2
# 2  cucumber, ponzu dressing, pickled ginger sprou...    5.0     2
# 3  sweet soy-marinated wakame seaweed threads, pi...    5.0     2
# 4  tempura battered tofu, katsuobushi, tsuyu brot...    5.0     2

# %%
report = dict ({'sales_item' : { 
    "01-count ": 0,
    "02-revenue ": 0,
    "03-cogs ": 0,
    "04-profit ": 0
}})

# %%
report
# Out:
# {'sales_item': {'01-count ': 0,
#   '02-revenue ': 0,
#   '03-cogs ': 0,
#   '04-profit ': 0}}

# %%
quantity_item_df= sales_df[["Quantity", "Menu_Item"]]

# %%
quantity_item_df
# Out:
#        Quantity              Menu_Item
# 0             1       spicy miso ramen
# 1             1       spicy miso ramen
# 2             3      tori paitan ramen
# 3             3      tori paitan ramen
# 4             1   truffle butter ramen
# ...         ...                    ...
# 74119         4         tonkotsu ramen
# 74120         1  vegetarian spicy miso
# 74121         1  vegetarian spicy miso
# 74122         2       spicy miso ramen
# 74123         2       spicy miso ramen
#
# [74124 rows x 2 columns]

# %%
quantity_item_df[{"Quantity", "Menu_Item"}]
# Out:
#                    Menu_Item  Quantity
# 0           spicy miso ramen         1
# 1           spicy miso ramen         1
# 2          tori paitan ramen         3
# 3          tori paitan ramen         3
# 4       truffle butter ramen         1
# ...                      ...       ...
# 74119         tonkotsu ramen         4
# 74120  vegetarian spicy miso         1
# 74121  vegetarian spicy miso         1
# 74122       spicy miso ramen         2
# 74123       spicy miso ramen         2
#
# [74124 rows x 2 columns]

# %%
##quantity_item_df[{"Quantity":1, "Menu_Item":1}
##for i in range(len(quantity_item_df)):
##      if quantity_item_df.loc[i,"Menu_Item"] == quantity_item_df.loc[i+1,"Menu_Item"]

# %%
##for i in range(1,len(quantity_item_df)):
##    if quantity_item_df.loc[["Menu_Item"], i] == quantity_item_df.loc[["Menu_Item"],i-1]:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sales_df.groupby("Menu_Item").agg(['sum'])[["revenue", "cogs", "profit", "Quantity"]]
